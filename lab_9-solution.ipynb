# %% [markdown]
# # Introduction to Programming
# ## Data wrangling - Lab 9
# ### Data preparation with string manipulation
#
# Import the very messy data in `MMG-2018.xlsx` which stores the missing migrant data for 2018.
# The data is stored in a single sheet per month.
# The data is pretty clean, but you still have a bit of preparation to do.
# You want to unify the records, reconstuct the dates, create unique identifiers, replace the column coordinates with columns for latitude and longitude, and finally try to extract the country of an event from textual information.
#
# Specifically, perform the following activities:
#
# - Create a connection with the excel file.
#
# - Write a for loop to iteratively import each sheet as a dataframe, remove redundant columns, and merge all dataframes together. Check that your code works as intended. For the purpose of the ensuing steps, it will be helpful to introduce a new column that stores the name of the month to which the data refer. This name can be found as the sheet name.
#
# - Reconstruct the dates of each occurrence in the format `<4-digit year>/<2-digit month>/<2-digit day>, <name of day of the week>`. Sort the dataframe in ascending chronological order.
#
#
# - Create unique identifiers for each record. These records should have the following structure `<year of the occurrence>.<4-digit unique integer label>`. For instance, the first record should be `2018.0001`.
#
# - Split the column `Coordinates` into a two columns `Latitude` and `Longitude` (this is the order in which they appear in `Coordinates`). Check that these columns are numeric, and convert them otherwise. Remove the column `Coordinates`. Compute descriptive statistics for the occurrences in the boreal and austral hemispheres.
#
# - Consider column `Location of death`. Note that the last word in each record often corresponds to the country of the event. Extract the last word and store it in a separate column `Country of event (tentative)`. In case you get here by the end of the lab: first, good job; second, try to refine the content of this column.

# %%
import pandas as pd

# %% [markdown]
# #### Unify dataframe

# %%
xls_file = pd.ExcelFile('MMG-2018.xlsx')

# %%
xls_file.sheet_names
# Out:
# ['Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Sep',
#  'Oct',
#  'Nov',
#  'Dec']

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# We loop over the names of the sheets, import the dataframes in each sheet using the `parse()` method of the `pd.ExcelFile` objects, and concatenate them vertically starting with an empty dataframe.

# %%
for sheet in xls_file.sheet_names:
    addendum = xls_file.parse(sheet)
#     alternatively:
#     addendum = pd.read_excel(xls_file, sheet)
    addendum['month'] = sheet
    df = pd.concat([df, addendum])

# %% [markdown]
# Check that this has worked properly.

# %%
df.head()
# Out:
#    Reported Day  Number Dead  Minimum Estimated Number of Missing  \
# 0             1          4.0                                  NaN
# 1             2          1.0                                  NaN
# 2             2          1.0                                  NaN
# 3             2          1.0                                  NaN
# 4             2          NaN                                  1.0
#
#    Total Number of Dead and Missing  Number of Survivors  Number of Females  \
# 0                                 4                  2.0                1.0
# 1                                 1                  NaN                NaN
# 2                                 1                  NaN                NaN
# 3                                 1                  NaN                NaN
# 4                                 1                  1.0                NaN
#
#    Number of Males  Number of Children  \
# 0              3.0                 NaN
# 1              1.0                 NaN
# 2              NaN                 NaN
# 3              1.0                 NaN
# 4              NaN                 NaN
#
#                                       Cause of Death  \
# 0  Vehicle accident / death linked to hazardous t...
# 1                                   Mixed or unknown
# 2                                   Mixed or unknown
# 3                                   Mixed or unknown
# 4                                           Drowning
#
#                                    Location of death  \
# 0  BR-471 motorway near Santa Vitória do Palmar,...
# 1  Pima Country Office of the Medical Examiner ju...
# 2   Ranch near Falfurrias, Brooks County, Texas, USA
# 3  Mariposa Ranch near Falfurrias, Brooks County,...
# 4  Kolpa/Kupa river, near Ukovaci, municipality o...
#
#                 Coordinates month
# 0  -33.5176991, -53.3342095   Jan
# 1    32.264014, -111.661872   Jan
# 2   27.2474839, -98.3788079   Jan
# 3    27.1058052, -98.146774   Jan
# 4    45.5597062, 15.2988207   Jan

# %%
df.tail()
# Out:
#     Reported Day  Number Dead  Minimum Estimated Number of Missing  \
# 94            28          1.0                                  NaN
# 95            30         14.0                                  NaN
# 96            30          NaN                                  1.0
# 97            31          1.0                                  NaN
# 98            31          2.0                                  NaN
#
#     Total Number of Dead and Missing  Number of Survivors  Number of Females  \
# 94                                 1                  NaN                NaN
# 95                                14                 12.0                NaN
# 96                                 1                  9.0                1.0
# 97                                 1                  NaN                NaN
# 98                                 2                  NaN                NaN
#
#     Number of Males  Number of Children  \
# 94              1.0                 NaN
# 95              NaN                 NaN
# 96              1.0                 1.0
# 97              NaN                 NaN
# 98              NaN                 NaN
#
#                                        Cause of Death  \
# 94                                           Drowning
# 95  Vehicle accident / death linked to hazardous t...
# 96                                           Drowning
# 97                                   Mixed or unknown
# 98                                   Mixed or unknown
#
#                                     Location of death  \
# 94  Off the coast of Imperial Beach, San Diego Cou...
# 95  Inside vehicle on Tanzania-Zambia highway, nea...
# 96   46 miles east of the Jupiter Inlet, Florida, USA
# 97  Pima Country Office of the Medical Examiner ju...
# 98                          Yuma County, Arizona, USA
#
#                   Coordinates month
# 94  32.54188202, -117.1337341   Dec
# 95  -6.840928719, 37.62619356   Dec
# 96    26.8304375, -79.5253125   Dec
# 97        32.27932, -112.8548   Dec
# 98   32.6926512, -114.6276916   Dec

# %%
df.isnull().all(axis=0).sum()
# Out:
# 0

# %%
df.isnull().all(axis=1).sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Reported Day                             int64
# Number Dead                            float64
# Minimum Estimated Number of Missing    float64
# Total Number of Dead and Missing         int64
# Number of Survivors                    float64
# Number of Females                      float64
# Number of Males                        float64
# Number of Children                     float64
# Cause of Death                          object
# Location of death                       object
# Coordinates                             object
# month                                   object
# dtype: object

# %% [markdown]
# #### Reconstruct dates

# %% [markdown]
# Use the `pandas` `str.cat()` method to concatenate strings. All elements in the concatenation need to be strings, so you need to cast any numbers to strings. This is similar to what you would do with the `+` operator between strings.

# %%
df['year'] = '2018'
df['Reported Day'].astype(str).str.cat([df['month'], df['year']], sep = '/')
# Out:
# 0      1/Jan/2018
# 1      2/Jan/2018
# 2      2/Jan/2018
# 3      2/Jan/2018
# 4      2/Jan/2018
#          ...
# 94    28/Dec/2018
# 95    30/Dec/2018
# 96    30/Dec/2018
# 97    31/Dec/2018
# 98    31/Dec/2018
# Name: Reported Day, Length: 1675, dtype: object

# %%
# alternatively
df[['Reported Day', 'month']].apply(lambda x : str(x[0]) + '/' + x[1] + '/2018', axis = 1)
# Out:
# 0      1/Jan/2018
# 1      2/Jan/2018
# 2      2/Jan/2018
# 3      2/Jan/2018
# 4      2/Jan/2018
#          ...
# 94    28/Dec/2018
# 95    30/Dec/2018
# 96    30/Dec/2018
# 97    31/Dec/2018
# 98    31/Dec/2018
# Length: 1675, dtype: object

# %% [markdown]
# Cast to datetime.

# %%
df['date'] = pd.to_datetime(df['Reported Day'].astype(str).str.cat([df['month'], df['year']], sep = '/'))

# %%
df['date']
# Out:
# 0    2018-01-01
# 1    2018-01-02
# 2    2018-01-02
# 3    2018-01-02
# 4    2018-01-02
#         ...
# 94   2018-12-28
# 95   2018-12-30
# 96   2018-12-30
# 97   2018-12-31
# 98   2018-12-31
# Name: date, Length: 1675, dtype: datetime64[ns]

# %%
df.drop(['year', 'month', 'Reported Day'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Number Dead  Minimum Estimated Number of Missing  \
# 0          4.0                                  NaN
# 1          1.0                                  NaN
# 2          1.0                                  NaN
# 3          1.0                                  NaN
# 4          NaN                                  1.0
#
#    Total Number of Dead and Missing  Number of Survivors  Number of Females  \
# 0                                 4                  2.0                1.0
# 1                                 1                  NaN                NaN
# 2                                 1                  NaN                NaN
# 3                                 1                  NaN                NaN
# 4                                 1                  1.0                NaN
#
#    Number of Males  Number of Children  \
# 0              3.0                 NaN
# 1              1.0                 NaN
# 2              NaN                 NaN
# 3              1.0                 NaN
# 4              NaN                 NaN
#
#                                       Cause of Death  \
# 0  Vehicle accident / death linked to hazardous t...
# 1                                   Mixed or unknown
# 2                                   Mixed or unknown
# 3                                   Mixed or unknown
# 4                                           Drowning
#
#                                    Location of death  \
# 0  BR-471 motorway near Santa Vitória do Palmar,...
# 1  Pima Country Office of the Medical Examiner ju...
# 2   Ranch near Falfurrias, Brooks County, Texas, USA
# 3  Mariposa Ranch near Falfurrias, Brooks County,...
# 4  Kolpa/Kupa river, near Ukovaci, municipality o...
#
#                 Coordinates       date
# 0  -33.5176991, -53.3342095 2018-01-01
# 1    32.264014, -111.661872 2018-01-02
# 2   27.2474839, -98.3788079 2018-01-02
# 3    27.1058052, -98.146774 2018-01-02
# 4    45.5597062, 15.2988207 2018-01-02

# %% [markdown]
# Use the function `datetime.strftime()` of the `datetime` builtin package to cast the dates into the desired format.

# %%
import datetime

# %%
df['date'].apply(lambda x : datetime.datetime.strftime(x, '%Y-%m-%d, %A'))
# Out:
# 0      2018-01-01, Monday
# 1     2018-01-02, Tuesday
# 2     2018-01-02, Tuesday
# 3     2018-01-02, Tuesday
# 4     2018-01-02, Tuesday
#              ...
# 94     2018-12-28, Friday
# 95     2018-12-30, Sunday
# 96     2018-12-30, Sunday
# 97     2018-12-31, Monday
# 98     2018-12-31, Monday
# Name: date, Length: 1675, dtype: object

# %%
def date_to_my_format(x) :
    return datetime.datetime.strftime(x, '%Y-%m-%d, %A')

# %%
df.iloc[0]['date']
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
date_to_my_format(df.iloc[0]['date'])
# Out:
# '2018-01-01, Monday'

# %%
df['date'].apply(date_to_my_format)
# Out:
# 0      2018-01-01, Monday
# 1     2018-01-02, Tuesday
# 2     2018-01-02, Tuesday
# 3     2018-01-02, Tuesday
# 4     2018-01-02, Tuesday
#              ...
# 94     2018-12-28, Friday
# 95     2018-12-30, Sunday
# 96     2018-12-30, Sunday
# 97     2018-12-31, Monday
# 98     2018-12-31, Monday
# Name: date, Length: 1675, dtype: object

# %%
df['date'] = df['date'].apply(lambda x : datetime.datetime.strftime(x, '%Y-%m-%d, %A'))

# %%
df.sort_values(by = 'date', inplace = True)
df.head(20)
# Out:
#      Number Dead  Minimum Estimated Number of Missing  \
# 0            4.0                                  NaN
# 1            1.0                                  NaN
# 2            1.0                                  NaN
# 3            1.0                                  NaN
# 4            NaN                                  1.0
# 5            2.0                                  NaN
# 6            1.0                                  NaN
# 7            2.0                                  NaN
# 8            1.0                                  NaN
# 9            1.0                                  NaN
# 10           4.0                                  NaN
# 11           1.0                                  NaN
# 13           3.0                                  NaN
# 12           8.0                                 56.0
# 14           2.0                                 10.0
# 15           1.0                                  NaN
# 16           1.0                                  NaN
# 17           NaN                                100.0
# 18           3.0                                  8.0
# 122          1.0                                  NaN
#
#      Total Number of Dead and Missing  Number of Survivors  Number of Females  \
# 0                                   4                  2.0                1.0
# 1                                   1                  NaN                NaN
# 2                                   1                  NaN                NaN
# 3                                   1                  NaN                NaN
# 4                                   1                  1.0                NaN
# 5                                   2                  NaN                NaN
# 6                                   1                  NaN                NaN
# 7                                   2                  NaN                1.0
# 8                                   1                  NaN                NaN
# 9                                   1                  NaN                NaN
# 10                                  4                  4.0                NaN
# 11                                  1                  NaN                NaN
# 13                                  3                  NaN                1.0
# 12                                 64                 86.0                6.0
# 14                                 12                270.0                2.0
# 15                                  1                  NaN                NaN
# 16                                  1                  NaN                NaN
# 17                                100                279.0                NaN
# 18                                 11                 43.0                NaN
# 122                                 1                  NaN                NaN
#
#      Number of Males  Number of Children  \
# 0                3.0                 NaN
# 1                1.0                 NaN
# 2                NaN                 NaN
# 3                1.0                 NaN
# 4                NaN                 NaN
# 5                2.0                 NaN
# 6                1.0                 NaN
# 7                1.0                 NaN
# 8                1.0                 NaN
# 9                1.0                 NaN
# 10               NaN                 NaN
# 11               1.0                 NaN
# 13               1.0                 NaN
# 12               2.0                 5.0
# 14               NaN                 NaN
# 15               1.0                 NaN
# 16               1.0                 NaN
# 17               NaN                 NaN
# 18               NaN                 NaN
# 122              1.0                 NaN
#
#                                         Cause of Death  \
# 0    Vehicle accident / death linked to hazardous t...
# 1                                     Mixed or unknown
# 2                                     Mixed or unknown
# 3                                     Mixed or unknown
# 4                                             Drowning
# 5                                     Mixed or unknown
# 6                                             Drowning
# 7                                     Mixed or unknown
# 8                                     Mixed or unknown
# 9                                             Drowning
# 10                                            Drowning
# 11   Harsh environmental conditions / lack of adequ...
# 13   Vehicle accident / death linked to hazardous t...
# 12                                    Mixed or unknown
# 14                                            Drowning
# 15                                            Violence
# 16   Vehicle accident / death linked to hazardous t...
# 17                                            Drowning
# 18                                            Drowning
# 122                                   Mixed or unknown
#
#                                      Location of death  \
# 0    BR-471 motorway near Santa Vitória do Palmar,...
# 1    Pima Country Office of the Medical Examiner ju...
# 2     Ranch near Falfurrias, Brooks County, Texas, USA
# 3    Mariposa Ranch near Falfurrias, Brooks County,...
# 4    Kolpa/Kupa river, near Ukovaci, municipality o...
# 5                                 Sahara desert, Libya
# 6    Rio Bravo, at Donna Rio Bravo International Br...
# 7                                 Sahara desert, Libya
# 8    East Ranch-Santa Fe Feeders, near Encino, 20 m...
# 9    Off the coast of Sanlúcar de Barrameda, Cádi...
# 10   Near Tanger-Med cargo port, 40km east of Tangi...
# 11                                Sahara desert, Sudan
# 13                                Sahara desert, Libya
# 12         Unspecified location off the coast of Libya
# 14                    Off the coast of Garabuli, Libya
# 15               Between Bani Waled and Tripoli, Libya
# 16      A16 motorway, km 90 near Marck, Calais, France
# 17                    Off the coast of Al Khums, Libya
# 18      Unspecified location between Morocco and Spain
# 122  Private ranch, 10 to 12 miles SW of Fort Davi...
#
#                    Coordinates                   date
# 0     -33.5176991, -53.3342095     2018-01-01, Monday
# 1       32.264014, -111.661872    2018-01-02, Tuesday
# 2      27.2474839, -98.3788079    2018-01-02, Tuesday
# 3       27.1058052, -98.146774    2018-01-02, Tuesday
# 4       45.5597062, 15.2988207    2018-01-02, Tuesday
# 5         21.284256, 24.028913    2018-01-02, Tuesday
# 6      26.0635489, -98.0760348  2018-01-03, Wednesday
# 7         24.642024, 14.587863  2018-01-03, Wednesday
# 8       26.8077686, -98.118294   2018-01-04, Thursday
# 9       36.7846768, -6.5809352   2018-01-04, Thursday
# 10      35.8805383, -5.5195052     2018-01-05, Friday
# 11        20.339476, 26.619864     2018-01-05, Friday
# 13        23.679744, 14.058795   2018-01-06, Saturday
# 12      34.0783805, 13.2682426   2018-01-06, Saturday
# 14      32.9830023, 13.7688521     2018-01-07, Sunday
# 15        31.876975, 13.853232     2018-01-08, Monday
# 16       50.9377278, 1.9495066    2018-01-09, Tuesday
# 17      33.4612462, 14.6304477    2018-01-09, Tuesday
# 18      35.8910058, -5.6593323    2018-01-09, Tuesday
# 122  30.56753899, -103.9873224    2018-01-09, Tuesday

# %% [markdown]
# #### Unique identifiers

# %% [markdown]
# An easy solution is to use the `format()` function and formatting conventions, which however we haven't covered.

# %%
# ?format
# Out:
# Signature: format(value, format_spec='', /)
# Docstring:
# Return value.__format__(format_spec)
#
# format_spec defaults to the empty string.
# See the Format Specification Mini-Language section of help('FORMATTING') for
# details.
# Type:      builtin_function_or_method

# %%
id = [ '2018.' + format(x, '04d') for x in range(0, len(df))]

# %%
id[:12]
# Out:
# ['2018.0000',
#  '2018.0001',
#  '2018.0002',
#  '2018.0003',
#  '2018.0004',
#  '2018.0005',
#  '2018.0006',
#  '2018.0007',
#  '2018.0008',
#  '2018.0009',
#  '2018.0010',
#  '2018.0011']

# %% [markdown]
# You can easily work around the need for this function by defining a function of your own.
# This function creates a string of as many zeros as required to get to 4 digits, given a number.

# %%
def four_digit_code (n):
    n_digit = len(str(n))
    return '0' * (4 -  n_digit) + str(n)

# %%
id = [ '2018.' + four_digit_code(x) for x in range(0, len(df))]
id[:12]
# Out:
# ['2018.0000',
#  '2018.0001',
#  '2018.0002',
#  '2018.0003',
#  '2018.0004',
#  '2018.0005',
#  '2018.0006',
#  '2018.0007',
#  '2018.0008',
#  '2018.0009',
#  '2018.0010',
#  '2018.0011']

# %% [markdown]
# Here I am choosing to use the id as a new index.

# %%
df.index = id
df
# Out:
#            Number Dead  Minimum Estimated Number of Missing  \
# 2018.0000          4.0                                  NaN
# 2018.0001          1.0                                  NaN
# 2018.0002          1.0                                  NaN
# 2018.0003          1.0                                  NaN
# 2018.0004          NaN                                  1.0
# ...                ...                                  ...
# 2018.1670          1.0                                  NaN
# 2018.1671         14.0                                  NaN
# 2018.1672          NaN                                  1.0
# 2018.1673          1.0                                  NaN
# 2018.1674          2.0                                  NaN
#
#            Total Number of Dead and Missing  Number of Survivors  \
# 2018.0000                                 4                  2.0
# 2018.0001                                 1                  NaN
# 2018.0002                                 1                  NaN
# 2018.0003                                 1                  NaN
# 2018.0004                                 1                  1.0
# ...                                     ...                  ...
# 2018.1670                                 1                  NaN
# 2018.1671                                14                 12.0
# 2018.1672                                 1                  9.0
# 2018.1673                                 1                  NaN
# 2018.1674                                 2                  NaN
#
#            Number of Females  Number of Males  Number of Children  \
# 2018.0000                1.0              3.0                 NaN
# 2018.0001                NaN              1.0                 NaN
# 2018.0002                NaN              NaN                 NaN
# 2018.0003                NaN              1.0                 NaN
# 2018.0004                NaN              NaN                 NaN
# ...                      ...              ...                 ...
# 2018.1670                NaN              1.0                 NaN
# 2018.1671                NaN              NaN                 NaN
# 2018.1672                1.0              1.0                 1.0
# 2018.1673                NaN              NaN                 NaN
# 2018.1674                NaN              NaN                 NaN
#
#                                               Cause of Death  \
# 2018.0000  Vehicle accident / death linked to hazardous t...
# 2018.0001                                   Mixed or unknown
# 2018.0002                                   Mixed or unknown
# 2018.0003                                   Mixed or unknown
# 2018.0004                                           Drowning
# ...                                                      ...
# 2018.1670                                           Drowning
# 2018.1671  Vehicle accident / death linked to hazardous t...
# 2018.1672                                           Drowning
# 2018.1673                                   Mixed or unknown
# 2018.1674                                   Mixed or unknown
#
#                                            Location of death  \
# 2018.0000  BR-471 motorway near Santa Vitória do Palmar,...
# 2018.0001  Pima Country Office of the Medical Examiner ju...
# 2018.0002   Ranch near Falfurrias, Brooks County, Texas, USA
# 2018.0003  Mariposa Ranch near Falfurrias, Brooks County,...
# 2018.0004  Kolpa/Kupa river, near Ukovaci, municipality o...
# ...                                                      ...
# 2018.1670  Off the coast of Imperial Beach, San Diego Cou...
# 2018.1671  Inside vehicle on Tanzania-Zambia highway, nea...
# 2018.1672   46 miles east of the Jupiter Inlet, Florida, USA
# 2018.1673  Pima Country Office of the Medical Examiner ju...
# 2018.1674                          Yuma County, Arizona, USA
#
#                          Coordinates                 date
# 2018.0000   -33.5176991, -53.3342095   2018-01-01, Monday
# 2018.0001     32.264014, -111.661872  2018-01-02, Tuesday
# 2018.0002    27.2474839, -98.3788079  2018-01-02, Tuesday
# 2018.0003     27.1058052, -98.146774  2018-01-02, Tuesday
# 2018.0004     45.5597062, 15.2988207  2018-01-02, Tuesday
# ...                              ...                  ...
# 2018.1670  32.54188202, -117.1337341   2018-12-28, Friday
# 2018.1671  -6.840928719, 37.62619356   2018-12-30, Sunday
# 2018.1672    26.8304375, -79.5253125   2018-12-30, Sunday
# 2018.1673        32.27932, -112.8548   2018-12-31, Monday
# 2018.1674   32.6926512, -114.6276916   2018-12-31, Monday
#
# [1675 rows x 11 columns]

# %% [markdown]
# #### Lat and lon

# %%
df['Coordinates'].str.split(', ')
# Out:
# 2018.0000     [-33.5176991, -53.3342095]
# 2018.0001       [32.264014, -111.661872]
# 2018.0002      [27.2474839, -98.3788079]
# 2018.0003       [27.1058052, -98.146774]
# 2018.0004       [45.5597062, 15.2988207]
#                         ...
# 2018.1670    [32.54188202, -117.1337341]
# 2018.1671    [-6.840928719, 37.62619356]
# 2018.1672      [26.8304375, -79.5253125]
# 2018.1673          [32.27932, -112.8548]
# 2018.1674     [32.6926512, -114.6276916]
# Name: Coordinates, Length: 1675, dtype: object

# %% [markdown]
# A safer formulation would be to use the RegEx for any number of whitespaces `\s+`.
# Here however the formulation above is sufficient.

# %%
df['Coordinates'].str.split(',\s+')
# Out:
# 2018.0000     [-33.5176991, -53.3342095]
# 2018.0001       [32.264014, -111.661872]
# 2018.0002      [27.2474839, -98.3788079]
# 2018.0003       [27.1058052, -98.146774]
# 2018.0004       [45.5597062, 15.2988207]
#                         ...
# 2018.1670    [32.54188202, -117.1337341]
# 2018.1671    [-6.840928719, 37.62619356]
# 2018.1672      [26.8304375, -79.5253125]
# 2018.1673          [32.27932, -112.8548]
# 2018.1674     [32.6926512, -114.6276916]
# Name: Coordinates, Length: 1675, dtype: object

# %%
df['Latitude'] = df['Coordinates'].str.split(', ').str[0].astype(float)

# %%
df['Longitude'] = df['Coordinates'].str.split(', ').str[1].astype(float)

# %%
df['Boreal'] = df['Latitude'] > 0

# %%
df.groupby('Boreal').describe()
# Out:
#        Number Dead                                                \
#              count      mean       std  min  25%  50%  75%   max
# Boreal
# False         53.0  2.188679  2.594792  1.0  1.0  1.0  2.0  14.0
# True        1555.0  1.967846  3.602015  1.0  1.0  1.0  2.0  64.0
#
#        Minimum Estimated Number of Missing             ...   Latitude  \
#                                      count       mean  ...        75%
# Boreal                                                 ...
# False                                  3.0   5.333333  ...  -4.872675
# True                                 116.0  15.474138  ...  32.682062
#
#                   Longitude                                               \
#               max     count       mean        std         min        25%
# Boreal
# False   -0.154338      52.0  29.832640  25.738864  -79.884198  32.715315
# True    51.193208    1622.0 -17.143743  57.526905 -117.133734 -97.517864
#
#
#               50%        75%         max
# Boreal
# False   34.128729  39.286525   45.100326
# True     7.965108  23.181283  120.955254
#
# [2 rows x 72 columns]

# %% [markdown]
# #### Tentative geography

# %%
location_split = df['Location of death'].str.split('\s+')
location_split
# Out:
# 2018.0000    [BR-471, motorway, near, Santa, Vitória, do, ...
# 2018.0001    [Pima, Country, Office, of, the, Medical, Exam...
# 2018.0002    [Ranch, near, Falfurrias,, Brooks, County,, Te...
# 2018.0003    [Mariposa, Ranch, near, Falfurrias,, Brooks, C...
# 2018.0004    [Kolpa/Kupa, river,, near, Ukovaci,, municipal...
#                                    ...
# 2018.1670    [Off, the, coast, of, Imperial, Beach,, San, D...
# 2018.1671    [Inside, vehicle, on, Tanzania-Zambia, highway...
# 2018.1672    [46, miles, east, of, the, Jupiter, Inlet,, Fl...
# 2018.1673    [Pima, Country, Office, of, the, Medical, Exam...
# 2018.1674                       [Yuma, County,, Arizona,, USA]
# Name: Location of death, Length: 1675, dtype: object

# %%
df['Country of event (tentative)'] = location_split.apply(lambda x : x[len(x) - 1])
df['Country of event (tentative)']
# Out:
# 2018.0000       Brazil
# 2018.0001    location)
# 2018.0002          USA
# 2018.0003          USA
# 2018.0004     Slovenia
#                ...
# 2018.1670          USA
# 2018.1671     Tanzania
# 2018.1672          USA
# 2018.1673    location)
# 2018.1674          USA
# Name: Country of event (tentative), Length: 1675, dtype: object

# %%
df.head()
# Out:
#            Number Dead  Minimum Estimated Number of Missing  \
# 2018.0000          4.0                                  NaN
# 2018.0001          1.0                                  NaN
# 2018.0002          1.0                                  NaN
# 2018.0003          1.0                                  NaN
# 2018.0004          NaN                                  1.0
#
#            Total Number of Dead and Missing  Number of Survivors  \
# 2018.0000                                 4                  2.0
# 2018.0001                                 1                  NaN
# 2018.0002                                 1                  NaN
# 2018.0003                                 1                  NaN
# 2018.0004                                 1                  1.0
#
#            Number of Females  Number of Males  Number of Children  \
# 2018.0000                1.0              3.0                 NaN
# 2018.0001                NaN              1.0                 NaN
# 2018.0002                NaN              NaN                 NaN
# 2018.0003                NaN              1.0                 NaN
# 2018.0004                NaN              NaN                 NaN
#
#                                               Cause of Death  \
# 2018.0000  Vehicle accident / death linked to hazardous t...
# 2018.0001                                   Mixed or unknown
# 2018.0002                                   Mixed or unknown
# 2018.0003                                   Mixed or unknown
# 2018.0004                                           Drowning
#
#                                            Location of death  \
# 2018.0000  BR-471 motorway near Santa Vitória do Palmar,...
# 2018.0001  Pima Country Office of the Medical Examiner ju...
# 2018.0002   Ranch near Falfurrias, Brooks County, Texas, USA
# 2018.0003  Mariposa Ranch near Falfurrias, Brooks County,...
# 2018.0004  Kolpa/Kupa river, near Ukovaci, municipality o...
#
#                         Coordinates                 date   Latitude  \
# 2018.0000  -33.5176991, -53.3342095   2018-01-01, Monday -33.517699
# 2018.0001    32.264014, -111.661872  2018-01-02, Tuesday  32.264014
# 2018.0002   27.2474839, -98.3788079  2018-01-02, Tuesday  27.247484
# 2018.0003    27.1058052, -98.146774  2018-01-02, Tuesday  27.105805
# 2018.0004    45.5597062, 15.2988207  2018-01-02, Tuesday  45.559706
#
#             Longitude  Boreal Country of event (tentative)
# 2018.0000  -53.334210   False                       Brazil
# 2018.0001 -111.661872    True                    location)
# 2018.0002  -98.378808    True                          USA
# 2018.0003  -98.146774    True                          USA
# 2018.0004   15.298821    True                     Slovenia
